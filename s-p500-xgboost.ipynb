# %% [markdown]
# # **S&P 500 Financial Forecasting with XgBoost**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# %% [markdown]
# ## Pre-Processing

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/kaggle/input/sandp500/all_stocks_5yr.csv")

df.head(3)
# Out:
#          date   open   high    low  close   volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75  8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46  8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27  8126000  AAL

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619029 entries, 0 to 619039
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    619029 non-null  datetime64[ns]
#  1   open    619029 non-null  float64
#  2   high    619029 non-null  float64
#  3   low     619029 non-null  float64
#  4   close   619029 non-null  float64
#  5   volume  619029 non-null  int64
#  6   Name    619029 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 37.8+ MB
# None
#         date   open   high    low  close    volume Name
# 0 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Goal:
# * Create more features from the exsisitng features within this data so we have more relevant data the model can learn from

# %%
# Creation of Additional Features from existing features
df['price_change'] = df['close'] - df['open']
df['high_low_range'] = df['high'] - df['low']
df['volume_change'] = df['volume'].pct_change()

# Setting up Moving Averages (MA's)
df['ma5'] = df['close'].rolling(window=5).mean()
df['ma10'] = df['close'].rolling(window=10).mean()
df['ma20'] = df['close'].rolling(window=20).mean()

# Shifted features for superivsed learnning (e.g. predicting tomorrows close)
df['close_shifted'] = df['close'].shift(-1)

df.dropna(inplace=True)

# %%
# 1. Relative Strength Index (RSI)
def calculate_rsi(series, window):
    delta = series.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

df['rsi_14'] = calculate_rsi(df['close'], 14)

# 2. Exponential Moving Average (EMA)
df['ema_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['ema_26'] = df['close'].ewm(span=26, adjust=False).mean()

# 3. Moving Average Convergence Divergence (MACD)
df['macd'] = df['ema_12'] - df['ema_26']
df['macd_signal'] = df['macd'].ewm(span=9, adjust=False).mean()

# 4. Bollinger Bands
df['bollinger_up'] = df['ma20'] + (df['close'].rolling(window=20).std() * 2)
df['bollinger_down'] = df['ma20'] - (df['close'].rolling(window=20).std() * 2)

# 5. Volume Weighted Average Price (VWAP)
df['vwap'] = (df['close'] * df['volume']).cumsum() / df['volume'].cumsum()

# 6. Lagged Features
df['close_lag1'] = df['close'].shift(1)
df['close_lag2'] = df['close'].shift(2)
df['close_lag5'] = df['close'].shift(5)

# 7. Temporal Features
df['day_of_week'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month
df['quarter'] = df['date'].dt.quarter

# 8. Interaction Features
df['price_volume_interaction'] = df['price_change'] * df['volume']
df['high_low_ratio'] = df['high'] / df['low']

# %% [markdown]
# ### **Goal:**
#
# * Split the data into training and testing sets for Inference

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name',
#        'price_change', 'high_low_range', 'volume_change', 'ma5', 'ma10',
#        'ma20', 'close_shifted', 'rsi_14', 'ema_12', 'ema_26', 'macd',
#        'macd_signal', 'bollinger_up', 'bollinger_down', 'vwap', 'close_lag1',
#        'close_lag2', 'close_lag5', 'day_of_week', 'month', 'quarter',
#        'price_volume_interaction', 'high_low_ratio'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Features we want the model to train on for modeling
X = df[['date', 'open', 'high', 'low', 'close', 'volume', 'Name',
       'price_change', 'high_low_range', 'volume_change', 'ma5', 'ma10',
       'ma20', 'rsi_14', 'ema_12', 'ema_26', 'macd', 'macd_signal', 
        'bollinger_up', 'bollinger_down', 'vwap', 'close_lag1', 
        'close_lag2', 'close_lag5', 'day_of_week', 'month', 
        'quarter', 'price_volume_interaction', 'high_low_ratio']]

y = df['close_shifted']

# Splitting the Data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

print(X_train.shape, X_test.shape)
# Out:
# (495207, 29) (123802, 29)

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# ## Model Training with XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
# Drop non-numeric columns that XGBoost cannot handle directly
X_train_numeric = X_train.drop(columns=['date', 'Name'])
X_test_numeric = X_test.drop(columns=['date', 'Name'])

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# Convert the numeric data into DMatrix format
train_data = xgb.DMatrix(X_train_numeric, label=y_train)
test_data = xgb.DMatrix(X_test_numeric, label=y_test)

# Define the parameters for XGBoost
params = {
    'objective': 'reg:squarederror',
    'max_depth': 6,
    'eta': 0.01,  # Lower learning rate
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'lambda': 1,  # L2 regularization
    'alpha': 0.1,  # L1 regularization
    'seed': 42
}

# Train the model
num_round = 1000
xgb_model = xgb.train(params, train_data, num_boost_round=num_round, evals=[(test_data, 'eval')],
                      early_stopping_rounds=50)

print("Model training complete.")
# Out:
# [0]	eval-rmse:45.74333
# [1]	eval-rmse:45.28811
# [2]	eval-rmse:44.83729
# [3]	eval-rmse:44.39032
# [4]	eval-rmse:43.94843
# [5]	eval-rmse:43.51100
# [6]	eval-rmse:43.07823
# [7]	eval-rmse:42.64877
# [8]	eval-rmse:42.22401
# [9]	eval-rmse:41.80311
# [10]	eval-rmse:41.38724
# [11]	eval-rmse:40.97563
# [12]	eval-rmse:40.56780
# [13]	eval-rmse:40.16460
# [14]	eval-rmse:39.76477
# [15]	eval-rmse:39.36920
# [16]	eval-rmse:38.97723
# [17]	eval-rmse:38.58835
# [18]	eval-rmse:38.20421
# [19]	eval-rmse:37.82362
# [20]	eval-rmse:37.44709
# [21]	eval-rmse:37.07480
# [22]	eval-rmse:36.70601
# [23]	eval-rmse:36.34153
# [24]	eval-rmse:35.98007
# [25]	eval-rmse:35.62223
# [26]	eval-rmse:35.26798
# [27]	eval-rmse:34.91663
# [28]	eval-rmse:34.56953
# [29]	eval-rmse:34.22610
# [30]	eval-rmse:33.88581
# [31]	eval-rmse:33.54966
# [32]	eval-rmse:33.21674
# [33]	eval-rmse:32.88713
# [34]	eval-rmse:32.56037
# [35]	eval-rmse:32.23718
# [36]	eval-rmse:31.91659
# [37]	eval-rmse:31.60003
# [38]	eval-rmse:31.28567
# [39]	eval-rmse:30.97532
# [40]	eval-rmse:30.66787
# [41]	eval-rmse:30.36410
# [42]	eval-rmse:30.06291
# [43]	eval-rmse:29.76505
# [44]	eval-rmse:29.46996
# [45]	eval-rmse:29.17770
# [46]	eval-rmse:28.88840
# [47]	eval-rmse:28.60146
# [48]	eval-rmse:28.31829
# [49]	eval-rmse:28.03770
# [50]	eval-rmse:27.76004
# [51]	eval-rmse:27.48443
# [52]	eval-rmse:27.21233
# [53]	eval-rmse:26.94302
# [54]	eval-rmse:26.67717
# [55]	eval-rmse:26.41258
# [56]	eval-rmse:26.15115
# [57]	eval-rmse:25.89267
# [58]	eval-rmse:25.63663
# [59]	eval-rmse:25.38311
# [60]	eval-rmse:25.13225
# [61]	eval-rmse:24.88391
# [62]	eval-rmse:24.63819
# [63]	eval-rmse:24.39443
# [64]	eval-rmse:24.15278
# [65]	eval-rmse:23.91426
# [66]	eval-rmse:23.67835
# [67]	eval-rmse:23.44469
# [68]	eval-rmse:23.21357
# [69]	eval-rmse:22.98458
# [70]	eval-rmse:22.75798
# [71]	eval-rmse:22.53451
# [72]	eval-rmse:22.31343
# [73]	eval-rmse:22.09372
# [74]	eval-rmse:21.87603
# [75]	eval-rmse:21.66069
# [76]	eval-rmse:21.44837
# [77]	eval-rmse:21.23817
# [78]	eval-rmse:21.02882
# [79]	eval-rmse:20.82218
# [80]	eval-rmse:20.61695
# [81]	eval-rmse:20.41385
# [82]	eval-rmse:20.21277
# [83]	eval-rmse:20.01389
# [84]	eval-rmse:19.81731
# [85]	eval-rmse:19.62361
# [86]	eval-rmse:19.43185
# [87]	eval-rmse:19.24138
# [88]	eval-rmse:19.05363
# [89]	eval-rmse:18.86646
# [90]	eval-rmse:18.68250
# [91]	eval-rmse:18.49961
# [92]	eval-rmse:18.31830
# [93]	eval-rmse:18.13926
# [94]	eval-rmse:17.96176
# [95]	eval-rmse:17.78670
# [96]	eval-rmse:17.61315
# [97]	eval-rmse:17.44143
# [98]	eval-rmse:17.27109
# [99]	eval-rmse:17.10315
# [100]	eval-rmse:16.93619
# [101]	eval-rmse:16.77128
# [102]	eval-rmse:16.60789
# [103]	eval-rmse:16.44710
# [104]	eval-rmse:16.28738
# [105]	eval-rmse:16.12908
# [106]	eval-rmse:15.97193
# [107]	eval-rmse:15.81682
# [108]	eval-rmse:15.66398
# [109]	eval-rmse:15.51160
# [110]	eval-rmse:15.36130
# [111]	eval-rmse:15.21268
# [112]	eval-rmse:15.06515
# [113]	eval-rmse:14.91999
# [114]	eval-rmse:14.77555
# [115]	eval-rmse:14.63289
# [116]	eval-rmse:14.49198
# [117]	eval-rmse:14.35229
# [118]	eval-rmse:14.21408
# [119]	eval-rmse:14.07685
# [120]	eval-rmse:13.94097
# [121]	eval-rmse:13.80661
# [122]	eval-rmse:13.67422
# [123]	eval-rmse:13.54353
# [124]	eval-rmse:13.41348
# [125]	eval-rmse:13.28496
# [126]	eval-rmse:13.15743
# [127]	eval-rmse:13.03173
# [128]	eval-rmse:12.90690
# [129]	eval-rmse:12.78346
# [130]	eval-rmse:12.66184
# [131]	eval-rmse:12.54177
# [132]	eval-rmse:12.42286
# [133]	eval-rmse:12.30447
# [134]	eval-rmse:12.18738
# [135]	eval-rmse:12.07204
# [136]	eval-rmse:11.95722
# [137]	eval-rmse:11.84406
# [138]	eval-rmse:11.73192
# [139]	eval-rmse:11.62126
# [140]	eval-rmse:11.51162
# [141]	eval-rmse:11.40318
# [142]	eval-rmse:11.29608
# [143]	eval-rmse:11.19027
# [144]	eval-rmse:11.08512
# [145]	eval-rmse:10.98156
# [146]	eval-rmse:10.87881
# [147]	eval-rmse:10.77661
# [148]	eval-rmse:10.67597
# [149]	eval-rmse:10.57649
# [150]	eval-rmse:10.47784
# [151]	eval-rmse:10.38024
# [152]	eval-rmse:10.28340
# [153]	eval-rmse:10.18781
# [154]	eval-rmse:10.09355
# [155]	eval-rmse:10.00027
# [156]	eval-rmse:9.90794
# [157]	eval-rmse:9.81636
# [158]	eval-rmse:9.72567
# [159]	eval-rmse:9.63629
# [160]	eval-rmse:9.54751
# [161]	eval-rmse:9.45971
# [162]	eval-rmse:9.37293
# [163]	eval-rmse:9.28731
# [164]	eval-rmse:9.20252
# [165]	eval-rmse:9.11840
# [166]	eval-rmse:9.03525
# [167]	eval-rmse:8.95337
# [168]	eval-rmse:8.87183
# [169]	eval-rmse:8.79139
# [170]	eval-rmse:8.71205
# [171]	eval-rmse:8.63351
# [172]	eval-rmse:8.55567
# [173]	eval-rmse:8.47866
# [174]	eval-rmse:8.40266
# [175]	eval-rmse:8.32794
# [176]	eval-rmse:8.25381
# [177]	eval-rmse:8.18058
# [178]	eval-rmse:8.10803
# [179]	eval-rmse:8.03637
# [180]	eval-rmse:7.96524
# [181]	eval-rmse:7.89470
# [182]	eval-rmse:7.82507
# [183]	eval-rmse:7.75622
# [184]	eval-rmse:7.68825
# [185]	eval-rmse:7.62153
# [186]	eval-rmse:7.55527
# [187]	eval-rmse:7.48985
# [188]	eval-rmse:7.42518
# [189]	eval-rmse:7.36098
# [190]	eval-rmse:7.29761
# [191]	eval-rmse:7.23518
# [192]	eval-rmse:7.17359
# [193]	eval-rmse:7.11230
# [194]	eval-rmse:7.05201
# [195]	eval-rmse:6.99211
# [196]	eval-rmse:6.93293
# [197]	eval-rmse:6.87411
# [198]	eval-rmse:6.81579
# [199]	eval-rmse:6.75851
# [200]	eval-rmse:6.70174
# [201]	eval-rmse:6.64582
# [202]	eval-rmse:6.59062
# [203]	eval-rmse:6.53608
# [204]	eval-rmse:6.48204
# [205]	eval-rmse:6.42888
# [206]	eval-rmse:6.37656
# [207]	eval-rmse:6.32485
# [208]	eval-rmse:6.27332
# [209]	eval-rmse:6.22255
# [210]	eval-rmse:6.17243
# [211]	eval-rmse:6.12263
# [212]	eval-rmse:6.07366
# [213]	eval-rmse:6.02518
# [214]	eval-rmse:5.97778
# [215]	eval-rmse:5.93076
# [216]	eval-rmse:5.88423
# [217]	eval-rmse:5.83784
# [218]	eval-rmse:5.79229
# [219]	eval-rmse:5.74715
# [220]	eval-rmse:5.70276
# [221]	eval-rmse:5.65897
# [222]	eval-rmse:5.61569
# [223]	eval-rmse:5.57316
# [224]	eval-rmse:5.53066
# [225]	eval-rmse:5.48863
# [226]	eval-rmse:5.44760
# [227]	eval-rmse:5.40681
# [228]	eval-rmse:5.36667
# [229]	eval-rmse:5.32704
# [230]	eval-rmse:5.28787
# [231]	eval-rmse:5.24904
# [232]	eval-rmse:5.21112
# [233]	eval-rmse:5.17340
# [234]	eval-rmse:5.13627
# [235]	eval-rmse:5.09919
# [236]	eval-rmse:5.06311
# [237]	eval-rmse:5.02720
# [238]	eval-rmse:4.99179
# [239]	eval-rmse:4.95704
# [240]	eval-rmse:4.92254
# [241]	eval-rmse:4.88849
# [242]	eval-rmse:4.85492
# [243]	eval-rmse:4.82216
# [244]	eval-rmse:4.78953
# [245]	eval-rmse:4.75718
# [246]	eval-rmse:4.72528
# [247]	eval-rmse:4.69408
# [248]	eval-rmse:4.66293
# [249]	eval-rmse:4.63223
# [250]	eval-rmse:4.60188
# [251]	eval-rmse:4.57192
# [252]	eval-rmse:4.54265
# [253]	eval-rmse:4.51365
# [254]	eval-rmse:4.48518
# [255]	eval-rmse:4.45713
# [256]	eval-rmse:4.42927
# [257]	eval-rmse:4.40206
# [258]	eval-rmse:4.37527
# [259]	eval-rmse:4.34885
# [260]	eval-rmse:4.32247
# [261]	eval-rmse:4.29680
# [262]	eval-rmse:4.27135
# [263]	eval-rmse:4.24622
# [264]	eval-rmse:4.22152
# [265]	eval-rmse:4.19713
# [266]	eval-rmse:4.17305
# [267]	eval-rmse:4.14922
# [268]	eval-rmse:4.12584
# [269]	eval-rmse:4.10282
# [270]	eval-rmse:4.08008
# [271]	eval-rmse:4.05771
# [272]	eval-rmse:4.03573
# [273]	eval-rmse:4.01415
# [274]	eval-rmse:3.99269
# [275]	eval-rmse:3.97139
# [276]	eval-rmse:3.95042
# [277]	eval-rmse:3.92993
# [278]	eval-rmse:3.90972
# [279]	eval-rmse:3.88976
# [280]	eval-rmse:3.87015
# [281]	eval-rmse:3.85094
# [282]	eval-rmse:3.83190
# [283]	eval-rmse:3.81323
# [284]	eval-rmse:3.79473
# [285]	eval-rmse:3.77655
# [286]	eval-rmse:3.75866
# [287]	eval-rmse:3.74102
# [288]	eval-rmse:3.72370
# [289]	eval-rmse:3.70662
# [290]	eval-rmse:3.68992
# [291]	eval-rmse:3.67347
# [292]	eval-rmse:3.65721
# [293]	eval-rmse:3.64120
# [294]	eval-rmse:3.62546
# [295]	eval-rmse:3.61003
# [296]	eval-rmse:3.59462
# [297]	eval-rmse:3.57957
# [298]	eval-rmse:3.56493
# [299]	eval-rmse:3.55029
# [300]	eval-rmse:3.53605
# [301]	eval-rmse:3.52191
# [302]	eval-rmse:3.50786
# [303]	eval-rmse:3.49430
# [304]	eval-rmse:3.48087
# [305]	eval-rmse:3.46773
# [306]	eval-rmse:3.45488
# [307]	eval-rmse:3.44205
# [308]	eval-rmse:3.42917
# [309]	eval-rmse:3.41684
# [310]	eval-rmse:3.40448
# [311]	eval-rmse:3.39245
# [312]	eval-rmse:3.38064
# [313]	eval-rmse:3.36885
# [314]	eval-rmse:3.35728
# [315]	eval-rmse:3.34588
# [316]	eval-rmse:3.33460
# [317]	eval-rmse:3.32373
# [318]	eval-rmse:3.31292
# [319]	eval-rmse:3.30254
# [320]	eval-rmse:3.29239
# [321]	eval-rmse:3.28226
# [322]	eval-rmse:3.27239
# [323]	eval-rmse:3.26274
# [324]	eval-rmse:3.25313
# [325]	eval-rmse:3.24384
# [326]	eval-rmse:3.23446
# [327]	eval-rmse:3.22537
# [328]	eval-rmse:3.21654
# [329]	eval-rmse:3.20779
# [330]	eval-rmse:3.19894
# [331]	eval-rmse:3.19045
# [332]	eval-rmse:3.18213
# [333]	eval-rmse:3.17393
# [334]	eval-rmse:3.16588
# [335]	eval-rmse:3.15782
# [336]	eval-rmse:3.15004
# [337]	eval-rmse:3.14214
# [338]	eval-rmse:3.13472
# [339]	eval-rmse:3.12725
# [340]	eval-rmse:3.11979
# [341]	eval-rmse:3.11276
# [342]	eval-rmse:3.10579
# [343]	eval-rmse:3.09898
# [344]	eval-rmse:3.09214
# [345]	eval-rmse:3.08544
# [346]	eval-rmse:3.07895
# [347]	eval-rmse:3.07254
# [348]	eval-rmse:3.06631
# [349]	eval-rmse:3.06037
# [350]	eval-rmse:3.05425
# [351]	eval-rmse:3.04832
# [352]	eval-rmse:3.04243
# [353]	eval-rmse:3.03669
# [354]	eval-rmse:3.03093
# [355]	eval-rmse:3.02532
# [356]	eval-rmse:3.01981
# [357]	eval-rmse:3.01437
# [358]	eval-rmse:3.00926
# [359]	eval-rmse:3.00406
# [360]	eval-rmse:2.99904
# [361]	eval-rmse:2.99390
# [362]	eval-rmse:2.98893
# [363]	eval-rmse:2.98403
# [364]	eval-rmse:2.97919
# [365]	eval-rmse:2.97451
# [366]	eval-rmse:2.97005
# [367]	eval-rmse:2.96549
# [368]	eval-rmse:2.96111
# [369]	eval-rmse:2.95672
# [370]	eval-rmse:2.95241
# [371]	eval-rmse:2.94819
# [372]	eval-rmse:2.94430
# [373]	eval-rmse:2.94035
# [374]	eval-rmse:2.93628
# [375]	eval-rmse:2.93174
# [376]	eval-rmse:2.92786
# [377]	eval-rmse:2.92417
# [378]	eval-rmse:2.92039
# [379]	eval-rmse:2.91678
# [380]	eval-rmse:2.91343
# [381]	eval-rmse:2.91001
# [382]	eval-rmse:2.90667
# [383]	eval-rmse:2.90335
# [384]	eval-rmse:2.90004
# [385]	eval-rmse:2.89693
# [386]	eval-rmse:2.89379
# [387]	eval-rmse:2.89023
# [388]	eval-rmse:2.88704
# [389]	eval-rmse:2.88396
# [390]	eval-rmse:2.88116
# [391]	eval-rmse:2.87823
# [392]	eval-rmse:2.87539
# [393]	eval-rmse:2.87263
# [394]	eval-rmse:2.86993
# [395]	eval-rmse:2.86727
# [396]	eval-rmse:2.86462
# [397]	eval-rmse:2.86207
# [398]	eval-rmse:2.85934
# [399]	eval-rmse:2.85646
# [400]	eval-rmse:2.85406
# [401]	eval-rmse:2.85159
# [402]	eval-rmse:2.84926
# [403]	eval-rmse:2.84680
# [404]	eval-rmse:2.84457
# [405]	eval-rmse:2.84239
# [406]	eval-rmse:2.84021
# [407]	eval-rmse:2.83818
# [408]	eval-rmse:2.83605
# [409]	eval-rmse:2.83406
# [410]	eval-rmse:2.83197
# [411]	eval-rmse:2.82992
# [412]	eval-rmse:2.82787
# [413]	eval-rmse:2.82598
# [414]	eval-rmse:2.82399
# [415]	eval-rmse:2.82224
# [416]	eval-rmse:2.82030
# [417]	eval-rmse:2.81858
# [418]	eval-rmse:2.81686
# [419]	eval-rmse:2.81512
# [420]	eval-rmse:2.81337
# [421]	eval-rmse:2.81165
# [422]	eval-rmse:2.80994
# [423]	eval-rmse:2.80836
# [424]	eval-rmse:2.80668
# [425]	eval-rmse:2.80511
# [426]	eval-rmse:2.80354
# [427]	eval-rmse:2.80208
# [428]	eval-rmse:2.80059
# [429]	eval-rmse:2.79916
# [430]	eval-rmse:2.79790
# [431]	eval-rmse:2.79653
# [432]	eval-rmse:2.79512
# [433]	eval-rmse:2.79370
# [434]	eval-rmse:2.79245
# [435]	eval-rmse:2.79117
# [436]	eval-rmse:2.78998
# [437]	eval-rmse:2.78859
# [438]	eval-rmse:2.78743
# [439]	eval-rmse:2.78617
# [440]	eval-rmse:2.78494
# [441]	eval-rmse:2.78383
# [442]	eval-rmse:2.78251
# [443]	eval-rmse:2.78140
# [444]	eval-rmse:2.78028
# [445]	eval-rmse:2.77930
# [446]	eval-rmse:2.77824
# [447]	eval-rmse:2.77712
# [448]	eval-rmse:2.77611
# [449]	eval-rmse:2.77499
# [450]	eval-rmse:2.77387
# [451]	eval-rmse:2.77284
# [452]	eval-rmse:2.77173
# [453]	eval-rmse:2.77046
# [454]	eval-rmse:2.76955
# [455]	eval-rmse:2.76829
# [456]	eval-rmse:2.76731
# [457]	eval-rmse:2.76590
# [458]	eval-rmse:2.76506
# [459]	eval-rmse:2.76398
# [460]	eval-rmse:2.76315
# [461]	eval-rmse:2.76231
# [462]	eval-rmse:2.76150
# [463]	eval-rmse:2.76054
# [464]	eval-rmse:2.75913
# [465]	eval-rmse:2.75845
# [466]	eval-rmse:2.75767
# [467]	eval-rmse:2.75688
# [468]	eval-rmse:2.75606
# [469]	eval-rmse:2.75536
# [470]	eval-rmse:2.75477
# [471]	eval-rmse:2.75393
# [472]	eval-rmse:2.75339
# [473]	eval-rmse:2.75286
# [474]	eval-rmse:2.75229
# [475]	eval-rmse:2.75172
# [476]	eval-rmse:2.75081
# [477]	eval-rmse:2.74955
# [478]	eval-rmse:2.74889
# [479]	eval-rmse:2.74829
# [480]	eval-rmse:2.74766
# [481]	eval-rmse:2.74707
# [482]	eval-rmse:2.74641
# [483]	eval-rmse:2.74582
# [484]	eval-rmse:2.74525
# [485]	eval-rmse:2.74479
# [486]	eval-rmse:2.74416
# [487]	eval-rmse:2.74368
# [488]	eval-rmse:2.74325
# [489]	eval-rmse:2.74251
# [490]	eval-rmse:2.74130
# [491]	eval-rmse:2.74081
# [492]	eval-rmse:2.74040
# [493]	eval-rmse:2.73973
# [494]	eval-rmse:2.73906
# [495]	eval-rmse:2.73886
# [496]	eval-rmse:2.73843
# [497]	eval-rmse:2.73780
# [498]	eval-rmse:2.73742
# [499]	eval-rmse:2.73687
# [500]	eval-rmse:2.73636
# [501]	eval-rmse:2.73590
# [502]	eval-rmse:2.73543
# [503]	eval-rmse:2.73501
# [504]	eval-rmse:2.73457
# [505]	eval-rmse:2.73413
# [506]	eval-rmse:2.73317
# [507]	eval-rmse:2.73249
# [508]	eval-rmse:2.73224
# [509]	eval-rmse:2.73169
# [510]	eval-rmse:2.73133
# [511]	eval-rmse:2.73097
# [512]	eval-rmse:2.73061
# [513]	eval-rmse:2.72987
# [514]	eval-rmse:2.72873
# [515]	eval-rmse:2.72848
# [516]	eval-rmse:2.72818
# [517]	eval-rmse:2.72795
# [518]	eval-rmse:2.72774
# [519]	eval-rmse:2.72752
# [520]	eval-rmse:2.72719
# [521]	eval-rmse:2.72700
# [522]	eval-rmse:2.72633
# [523]	eval-rmse:2.72596
# [524]	eval-rmse:2.72558
# [525]	eval-rmse:2.72494
# [526]	eval-rmse:2.72423
# [527]	eval-rmse:2.72402
# [528]	eval-rmse:2.72378
# [529]	eval-rmse:2.72339
# [530]	eval-rmse:2.72317
# [531]	eval-rmse:2.72302
# [532]	eval-rmse:2.72273
# [533]	eval-rmse:2.72199
# [534]	eval-rmse:2.72159
# [535]	eval-rmse:2.72142
# [536]	eval-rmse:2.72124
# [537]	eval-rmse:2.72105
# [538]	eval-rmse:2.72039
# [539]	eval-rmse:2.72014
# [540]	eval-rmse:2.71991
# [541]	eval-rmse:2.71929
# [542]	eval-rmse:2.71870
# [543]	eval-rmse:2.71848
# [544]	eval-rmse:2.71827
# [545]	eval-rmse:2.71812
# [546]	eval-rmse:2.71760
# [547]	eval-rmse:2.71734
# [548]	eval-rmse:2.71700
# [549]	eval-rmse:2.71675
# [550]	eval-rmse:2.71654
# [551]	eval-rmse:2.71484
# [552]	eval-rmse:2.71450
# [553]	eval-rmse:2.71428
# [554]	eval-rmse:2.71408
# [555]	eval-rmse:2.71386
# [556]	eval-rmse:2.71350
# [557]	eval-rmse:2.71290
# [558]	eval-rmse:2.71248
# [559]	eval-rmse:2.71220
# [560]	eval-rmse:2.71200
# [561]	eval-rmse:2.71178
# [562]	eval-rmse:2.71165
# [563]	eval-rmse:2.71123
# [564]	eval-rmse:2.71113
# [565]	eval-rmse:2.71099
# [566]	eval-rmse:2.71054
# [567]	eval-rmse:2.71036
# [568]	eval-rmse:2.70991
# [569]	eval-rmse:2.70951
# [570]	eval-rmse:2.70902
# [571]	eval-rmse:2.70892
# [572]	eval-rmse:2.70849
# [573]	eval-rmse:2.70835
# [574]	eval-rmse:2.70812
# [575]	eval-rmse:2.70790
# [576]	eval-rmse:2.70772
# [577]	eval-rmse:2.70757
# [578]	eval-rmse:2.70730
# [579]	eval-rmse:2.70693
# [580]	eval-rmse:2.70675
# [581]	eval-rmse:2.70605
# [582]	eval-rmse:2.70594
# [583]	eval-rmse:2.70566
# [584]	eval-rmse:2.70522
# [585]	eval-rmse:2.70508
# [586]	eval-rmse:2.70485
# [587]	eval-rmse:2.70385
# [588]	eval-rmse:2.70329
# [589]	eval-rmse:2.70242
# [590]	eval-rmse:2.70210
# [591]	eval-rmse:2.70199
# [592]	eval-rmse:2.70166
# [593]	eval-rmse:2.70078
# [594]	eval-rmse:2.70050
# [595]	eval-rmse:2.70044
# [596]	eval-rmse:2.70032
# [597]	eval-rmse:2.69973
# [598]	eval-rmse:2.69927
# [599]	eval-rmse:2.69919
# [600]	eval-rmse:2.69859
# [601]	eval-rmse:2.69788
# [602]	eval-rmse:2.69753
# [603]	eval-rmse:2.69741
# [604]	eval-rmse:2.69734
# [605]	eval-rmse:2.69701
# [606]	eval-rmse:2.69647
# [607]	eval-rmse:2.69585
# [608]	eval-rmse:2.69587
# [609]	eval-rmse:2.69556
# [610]	eval-rmse:2.69528
# [611]	eval-rmse:2.69524
# [612]	eval-rmse:2.69511
# [613]	eval-rmse:2.69496
# [614]	eval-rmse:2.69485
# [615]	eval-rmse:2.69433
# [616]	eval-rmse:2.69419
# [617]	eval-rmse:2.69321
# [618]	eval-rmse:2.69317
# [619]	eval-rmse:2.69306
# [620]	eval-rmse:2.69257
# [621]	eval-rmse:2.69229
# [622]	eval-rmse:2.69197
# [623]	eval-rmse:2.69166
# [624]	eval-rmse:2.69153
# [625]	eval-rmse:2.69130
# [626]	eval-rmse:2.69124
# [627]	eval-rmse:2.69115
# [628]	eval-rmse:2.69094
# [629]	eval-rmse:2.69095
# [630]	eval-rmse:2.69078
# [631]	eval-rmse:2.69071
# [632]	eval-rmse:2.69049
# [633]	eval-rmse:2.69004
# [634]	eval-rmse:2.69000
# [635]	eval-rmse:2.68994
# [636]	eval-rmse:2.68964
# [637]	eval-rmse:2.68921
# [638]	eval-rmse:2.68918
# [639]	eval-rmse:2.68881
# [640]	eval-rmse:2.68874
# [641]	eval-rmse:2.68870
# [642]	eval-rmse:2.68875
# [643]	eval-rmse:2.68865
# [644]	eval-rmse:2.68809
# [645]	eval-rmse:2.68800
# [646]	eval-rmse:2.68785
# [647]	eval-rmse:2.68780
# [648]	eval-rmse:2.68771
# [649]	eval-rmse:2.68761
# [650]	eval-rmse:2.68761
# [651]	eval-rmse:2.68742
# [652]	eval-rmse:2.68735
# [653]	eval-rmse:2.68733
# [654]	eval-rmse:2.68733
# [655]	eval-rmse:2.68733
# [656]	eval-rmse:2.68728
# [657]	eval-rmse:2.68716
# [658]	eval-rmse:2.68712
# [659]	eval-rmse:2.68712
# [660]	eval-rmse:2.68683
# [661]	eval-rmse:2.68622
# [662]	eval-rmse:2.68620
# [663]	eval-rmse:2.68605
# [664]	eval-rmse:2.68601
# [665]	eval-rmse:2.68591
# [666]	eval-rmse:2.68530
# [667]	eval-rmse:2.68504
# [668]	eval-rmse:2.68496
# [669]	eval-rmse:2.68493
# [670]	eval-rmse:2.68472
# [671]	eval-rmse:2.68412
# [672]	eval-rmse:2.68398
# [673]	eval-rmse:2.68398
# [674]	eval-rmse:2.68381
# [675]	eval-rmse:2.68376
# [676]	eval-rmse:2.68347
# [677]	eval-rmse:2.68344
# [678]	eval-rmse:2.68325
# [679]	eval-rmse:2.68315
# [680]	eval-rmse:2.68313
# [681]	eval-rmse:2.68305
# [682]	eval-rmse:2.68305
# [683]	eval-rmse:2.68304
# [684]	eval-rmse:2.68299
# [685]	eval-rmse:2.68211
# [686]	eval-rmse:2.68200
# [687]	eval-rmse:2.68188
# [688]	eval-rmse:2.68181
# [689]	eval-rmse:2.68172
# [690]	eval-rmse:2.68171
# [691]	eval-rmse:2.68163
# [692]	eval-rmse:2.68158
# [693]	eval-rmse:2.68152
# [694]	eval-rmse:2.68150
# [695]	eval-rmse:2.68149
# [696]	eval-rmse:2.68148
# [697]	eval-rmse:2.68146
# [698]	eval-rmse:2.68145
# [699]	eval-rmse:2.68144
# [700]	eval-rmse:2.68082
# [701]	eval-rmse:2.68076
# [702]	eval-rmse:2.68075
# [703]	eval-rmse:2.68058
# [704]	eval-rmse:2.68059
# [705]	eval-rmse:2.68057
# [706]	eval-rmse:2.68056
# [707]	eval-rmse:2.68052
# [708]	eval-rmse:2.68047
# [709]	eval-rmse:2.68041
# [710]	eval-rmse:2.68043
# [711]	eval-rmse:2.68042
# [712]	eval-rmse:2.68042
# [713]	eval-rmse:2.68036
# [714]	eval-rmse:2.68035
# [715]	eval-rmse:2.68035
# [716]	eval-rmse:2.68028
# [717]	eval-rmse:2.68024
# [718]	eval-rmse:2.68024
# [719]	eval-rmse:2.68024
# [720]	eval-rmse:2.68021
# [721]	eval-rmse:2.68018
# [722]	eval-rmse:2.68022
# [723]	eval-rmse:2.68007
# [724]	eval-rmse:2.68007
# [725]	eval-rmse:2.67994
# [726]	eval-rmse:2.67995
# [727]	eval-rmse:2.67992
# [728]	eval-rmse:2.67990
# [729]	eval-rmse:2.67989
# [730]	eval-rmse:2.67992
# [731]	eval-rmse:2.67983
# [732]	eval-rmse:2.67980
# [733]	eval-rmse:2.67973
# [734]	eval-rmse:2.67972
# [735]	eval-rmse:2.67948
# [736]	eval-rmse:2.67880
# [737]	eval-rmse:2.67882
# [738]	eval-rmse:2.67882
# [739]	eval-rmse:2.67883
# [740]	eval-rmse:2.67886
# [741]	eval-rmse:2.67890
# [742]	eval-rmse:2.67884
# [743]	eval-rmse:2.67893
# [744]	eval-rmse:2.67892
# [745]	eval-rmse:2.67892
# [746]	eval-rmse:2.67895
# [747]	eval-rmse:2.67897
# [748]	eval-rmse:2.67897
# [749]	eval-rmse:2.67869
# [750]	eval-rmse:2.67869
# [751]	eval-rmse:2.67814
# [752]	eval-rmse:2.67817
# [753]	eval-rmse:2.67819
# [754]	eval-rmse:2.67822
# [755]	eval-rmse:2.67821
# [756]	eval-rmse:2.67816
# [757]	eval-rmse:2.67758
# [758]	eval-rmse:2.67751
# [759]	eval-rmse:2.67744
# [760]	eval-rmse:2.67744
# [761]	eval-rmse:2.67744
# [762]	eval-rmse:2.67734
# [763]	eval-rmse:2.67733
# [764]	eval-rmse:2.67736
# [765]	eval-rmse:2.67736
# [766]	eval-rmse:2.67736
# [767]	eval-rmse:2.67740
# [768]	eval-rmse:2.67738
# [769]	eval-rmse:2.67731
# [770]	eval-rmse:2.67729
# [771]	eval-rmse:2.67725
# [772]	eval-rmse:2.67715
# [773]	eval-rmse:2.67710
# [774]	eval-rmse:2.67710
# [775]	eval-rmse:2.67710
# [776]	eval-rmse:2.67711
# [777]	eval-rmse:2.67710
# [778]	eval-rmse:2.67710
# [779]	eval-rmse:2.67707
# [780]	eval-rmse:2.67711
# [781]	eval-rmse:2.67711
# [782]	eval-rmse:2.67611
# [783]	eval-rmse:2.67620
# [784]	eval-rmse:2.67620
# [785]	eval-rmse:2.67618
# [786]	eval-rmse:2.67618
# [787]	eval-rmse:2.67618
# [788]	eval-rmse:2.67617
# [789]	eval-rmse:2.67616
# [790]	eval-rmse:2.67614
# [791]	eval-rmse:2.67626
# [792]	eval-rmse:2.67605
# [793]	eval-rmse:2.67606
# [794]	eval-rmse:2.67605
# [795]	eval-rmse:2.67582
# [796]	eval-rmse:2.67584
# [797]	eval-rmse:2.67583
# [798]	eval-rmse:2.67583
# [799]	eval-rmse:2.67591
# [800]	eval-rmse:2.67589
# [801]	eval-rmse:2.67589
# [802]	eval-rmse:2.67587
# [803]	eval-rmse:2.67586
# [804]	eval-rmse:2.67586
# [805]	eval-rmse:2.67585
# [806]	eval-rmse:2.67579
# [807]	eval-rmse:2.67589
# [808]	eval-rmse:2.67586
# [809]	eval-rmse:2.67584
# [810]	eval-rmse:2.67588
# [811]	eval-rmse:2.67476
# [812]	eval-rmse:2.67476
# [813]	eval-rmse:2.67476
# [814]	eval-rmse:2.67474
# [815]	eval-rmse:2.67476
# [816]	eval-rmse:2.67472
# [817]	eval-rmse:2.67466
# [818]	eval-rmse:2.67471
# [819]	eval-rmse:2.67472
# [820]	eval-rmse:2.67472
# [821]	eval-rmse:2.67473
# [822]	eval-rmse:2.67473
# [823]	eval-rmse:2.67471
# [824]	eval-rmse:2.67468
# [825]	eval-rmse:2.67467
# [826]	eval-rmse:2.67467
# [827]	eval-rmse:2.67461
# [828]	eval-rmse:2.67458
# [829]	eval-rmse:2.67458
# [830]	eval-rmse:2.67462
# [831]	eval-rmse:2.67462
# [832]	eval-rmse:2.67461
# [833]	eval-rmse:2.67464
# [834]	eval-rmse:2.67466
# [835]	eval-rmse:2.67464
# [836]	eval-rmse:2.67464
# [837]	eval-rmse:2.67458
# [838]	eval-rmse:2.67456
# [839]	eval-rmse:2.67452
# [840]	eval-rmse:2.67451
# [841]	eval-rmse:2.67451
# [842]	eval-rmse:2.67445
# [843]	eval-rmse:2.67418
# [844]	eval-rmse:2.67411
# [845]	eval-rmse:2.67403
# [846]	eval-rmse:2.67398
# [847]	eval-rmse:2.67404
# [848]	eval-rmse:2.67401
# [849]	eval-rmse:2.67401
# [850]	eval-rmse:2.67347
# [851]	eval-rmse:2.67353
# [852]	eval-rmse:2.67353
# [853]	eval-rmse:2.67345
# [854]	eval-rmse:2.67346
# [855]	eval-rmse:2.67347
# [856]	eval-rmse:2.67347
# [857]	eval-rmse:2.67347
# [858]	eval-rmse:2.67341
# [859]	eval-rmse:2.67340
# [860]	eval-rmse:2.67338
# [861]	eval-rmse:2.67338
# [862]	eval-rmse:2.67328
# [863]	eval-rmse:2.67276
# [864]	eval-rmse:2.67275
# [865]	eval-rmse:2.67270
# [866]	eval-rmse:2.67265
# [867]	eval-rmse:2.67266
# [868]	eval-rmse:2.67260
# [869]	eval-rmse:2.67259
# [870]	eval-rmse:2.67217
# [871]	eval-rmse:2.67217
# [872]	eval-rmse:2.67215
# [873]	eval-rmse:2.67216
# [874]	eval-rmse:2.67208
# [875]	eval-rmse:2.67207
# [876]	eval-rmse:2.67205
# [877]	eval-rmse:2.67199
# [878]	eval-rmse:2.67198
# [879]	eval-rmse:2.67199
# [880]	eval-rmse:2.67199
# [881]	eval-rmse:2.67199
# [882]	eval-rmse:2.67198
# [883]	eval-rmse:2.67198
# [884]	eval-rmse:2.67197
# [885]	eval-rmse:2.67194
# [886]	eval-rmse:2.67195
# [887]	eval-rmse:2.67195
# [888]	eval-rmse:2.67196
# [889]	eval-rmse:2.67195
# [890]	eval-rmse:2.67196
# [891]	eval-rmse:2.67195
# [892]	eval-rmse:2.67203
# [893]	eval-rmse:2.67204
# [894]	eval-rmse:2.67207
# [895]	eval-rmse:2.67207
# [896]	eval-rmse:2.67207
# [897]	eval-rmse:2.67206
# [898]	eval-rmse:2.67205
# [899]	eval-rmse:2.67196
# [900]	eval-rmse:2.67200
# [901]	eval-rmse:2.67215
# [902]	eval-rmse:2.67214
# [903]	eval-rmse:2.67210
# [904]	eval-rmse:2.67210
# [905]	eval-rmse:2.67209
# [906]	eval-rmse:2.67207
# [907]	eval-rmse:2.67218
# [908]	eval-rmse:2.67215
# [909]	eval-rmse:2.67219
# [910]	eval-rmse:2.67220
# [911]	eval-rmse:2.67209
# [912]	eval-rmse:2.67220
# [913]	eval-rmse:2.67220
# [914]	eval-rmse:2.67224
# [915]	eval-rmse:2.67156
# [916]	eval-rmse:2.67151
# [917]	eval-rmse:2.67151
# [918]	eval-rmse:2.67151
# [919]	eval-rmse:2.67065
# [920]	eval-rmse:2.67065
# [921]	eval-rmse:2.67057
# [922]	eval-rmse:2.67058
# [923]	eval-rmse:2.67057
# [924]	eval-rmse:2.67065
# [925]	eval-rmse:2.67065
# [926]	eval-rmse:2.67058
# [927]	eval-rmse:2.67058
# [928]	eval-rmse:2.67058
# [929]	eval-rmse:2.67057
# [930]	eval-rmse:2.67050
# [931]	eval-rmse:2.67049
# [932]	eval-rmse:2.67047
# [933]	eval-rmse:2.67047
# [934]	eval-rmse:2.67042
# [935]	eval-rmse:2.67002
# [936]	eval-rmse:2.67002
# [937]	eval-rmse:2.66999
# [938]	eval-rmse:2.66999
# [939]	eval-rmse:2.66999
# [940]	eval-rmse:2.66999
# [941]	eval-rmse:2.66987
# [942]	eval-rmse:2.66987
# [943]	eval-rmse:2.66987
# [944]	eval-rmse:2.66986
# [945]	eval-rmse:2.66985
# [946]	eval-rmse:2.66984
# [947]	eval-rmse:2.66987
# [948]	eval-rmse:2.66991
# [949]	eval-rmse:2.66978
# [950]	eval-rmse:2.66978
# [951]	eval-rmse:2.66972
# [952]	eval-rmse:2.66972
# [953]	eval-rmse:2.66972
# [954]	eval-rmse:2.66973
# [955]	eval-rmse:2.66926
# [956]	eval-rmse:2.66922
# [957]	eval-rmse:2.66922
# [958]	eval-rmse:2.66922
# [959]	eval-rmse:2.66893
# [960]	eval-rmse:2.66890
# [961]	eval-rmse:2.66851
# [962]	eval-rmse:2.66851
# [963]	eval-rmse:2.66777
# [964]	eval-rmse:2.66776
# [965]	eval-rmse:2.66776
# [966]	eval-rmse:2.66776
# [967]	eval-rmse:2.66776
# [968]	eval-rmse:2.66763
# [969]	eval-rmse:2.66763
# [970]	eval-rmse:2.66760
# [971]	eval-rmse:2.66738
# [972]	eval-rmse:2.66740
# [973]	eval-rmse:2.66736
# [974]	eval-rmse:2.66736
# [975]	eval-rmse:2.66736
# [976]	eval-rmse:2.66736
# [977]	eval-rmse:2.66747
# [978]	eval-rmse:2.66747
# [979]	eval-rmse:2.66746
# [980]	eval-rmse:2.66746
# [981]	eval-rmse:2.66746
# [982]	eval-rmse:2.66746
# [983]	eval-rmse:2.66745
# [984]	eval-rmse:2.66746
# [985]	eval-rmse:2.66744
# [986]	eval-rmse:2.66744
# [987]	eval-rmse:2.66744
# [988]	eval-rmse:2.66744
# [989]	eval-rmse:2.66744
# [990]	eval-rmse:2.66744
# [991]	eval-rmse:2.66728
# [992]	eval-rmse:2.66725
# [993]	eval-rmse:2.66726
# [994]	eval-rmse:2.66731
# [995]	eval-rmse:2.66730
# [996]	eval-rmse:2.66715
# [997]	eval-rmse:2.66715
# [998]	eval-rmse:2.66706
# [999]	eval-rmse:2.66705
# Model training complete.

# %%
# Predict on the test set
y_pred = xgb_model.predict(test_data)

# Evaluate the model
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Additional Model Evaluation
print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
# Out:
# Root Mean Squared Error (RMSE): 2.6670527669838164
# Mean Squared Error (MSE): 7.113170461876031

# %% [markdown]
# ## **Hyper-Param Tuning**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# More features
df['rsi_14'] = calculate_rsi(df['close'], 14)
df['ema_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['ema_26'] = df['close'].ewm(span=26, adjust=False).mean()
df['macd'] = df['ema_12'] - df['ema_26']
df['macd_signal'] = df['macd'].ewm(span=9, adjust=False).mean()
df['bollinger_up'] = df['ma20'] + (df['close'].rolling(window=20).std() * 2)
df['bollinger_down'] = df['ma20'] - (df['close'].rolling(window=20).std() * 2)
df['vwap'] = (df['close'] * df['volume']).cumsum() / df['volume'].cumsum()
df['close_lag1'] = df['close'].shift(1)
df['close_lag2'] = df['close'].shift(2)
df['close_lag5'] = df['close'].shift(5)
df['day_of_week'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month
df['quarter'] = df['date'].dt.quarter
df['price_volume_interaction'] = df['price_change'] * df['volume']
df['high_low_ratio'] = df['high'] / df['low']

df.dropna(inplace=True)

# Prepare data for training
X = df[['open', 'high', 'low', 'close', 'volume', 'price_change', 'high_low_range', 
        'volume_change', 'ma5', 'ma10', 'ma20', 'rsi_14', 'ema_12', 'ema_26', 
        'macd', 'macd_signal', 'bollinger_up', 'bollinger_down', 'vwap', 
        'close_lag1', 'close_lag2', 'close_lag5', 'day_of_week', 'month', 
        'quarter', 'price_volume_interaction', 'high_low_ratio']]
y = df['close_shifted']

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define parameter grid for GridSearchCV
param_grid = {
    'max_depth': [3, 5],
    'eta': [0.01, 0.1],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'lambda': [1],
    'alpha': [0, 0.1]
}

# Initializing XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', seed=42, n_estimators=100)

# Setting up GridSearchCV
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5, 
                           scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

# Fitting GridSearchCV
grid_search.fit(X_train_scaled, y_train)

# Best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best RMSE (negative MSE):", np.sqrt(-grid_search.best_score_))

# Training final model using best parameters
best_params = grid_search.best_params_
xgb_model_final = xgb.XGBRegressor(**best_params, objective='reg:squarederror', n_estimators=100, seed=42)
xgb_model_final.fit(X_train_scaled, y_train)

# Predicting and evaluating on test set
y_pred = xgb_model_final.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Test RMSE: {rmse}")
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Parameters: {'alpha': 0, 'colsample_bytree': 0.8, 'eta': 0.1, 'lambda': 1, 'max_depth': 3, 'subsample': 0.8}
# Best RMSE (negative MSE): 29.987652278464825
# Test RMSE: 2.985220725880869
